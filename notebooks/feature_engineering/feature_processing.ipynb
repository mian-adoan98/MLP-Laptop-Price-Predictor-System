# %% [markdown]
# # Feature Processing: P2

# %%
# Import libraries
import pandas as pd 
import numpy as np 
import os, sys 

sys.path.append(os.path.abspath(".."))

# %% [markdown]
# ## Data Loading

# %%
# Implement functionalities
from scripts.collection.collector import DataLoader

# %%
# Load 4 datasets 
data_loader = DataLoader(folder="processed/v1")
visual_data = data_loader.load("visual_table.csv")
# Out:
# File accepted

# %%
visual_data
# Out:
#      SCREEN_ID  SCREEN_SIZE_INCH  COLOR  WIDTH_DISPLAY  HEIGHT_DISPLAY  \
# 0           S0             14.00   gray         2160.0          1440.0
# 1           S1             14.00  black         1920.0          1080.0
# 2           S2             11.60  black         1366.0           768.0
# 3           S3             12.50  other         1366.0           768.0
# 4           S4             11.60  black         1366.0           768.0
# ...        ...               ...    ...            ...             ...
# 4178     S4178              8.43  other         1920.0          1080.0
# 4179     S4179             12.50  black         1920.0          1080.0
# 4180     S4180              8.43  other         1920.0          1080.0
# 4181     S4181              8.43  black         1920.0          1080.0
# 4182       NaN               NaN    NaN            NaN             NaN
#
#      DISPLAY WEBCAM(BUILT-IN)
# 0         NO              YES
# 1        YES              YES
# ...

# %%
visual_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4183 entries, 0 to 4182
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   SCREEN_ID         4182 non-null   object
#  1   SCREEN_SIZE_INCH  4182 non-null   float64
#  2   COLOR             4182 non-null   object
#  3   WIDTH_DISPLAY     4182 non-null   float64
#  4   HEIGHT_DISPLAY    4182 non-null   float64
#  5   DISPLAY           4183 non-null   object
#  6   WEBCAM(BUILT-IN)  4183 non-null   object
# dtypes: float64(3), object(4)
# memory usage: 261.4+ KB

# %% [markdown]
# ### Approach

# %% [markdown]
# + Feature Transformation: converting unit to SI-unit (SCREEN_SIZE_INCH to SCREEN_SIZE_CM)
# + Feature Encoding: apply encoding on binary features (WebCAM, DISPLAY, etc.)
# + Data Storage

# %% [markdown]
# ## Feature Transformation

# %%
# Import functionalities
from scripts.processing.transformer import ColumnTransformer
from scripts.analysis.irrelevant_data_analyser import InconInspector
from scripts.processing.cleaner import InconRemover
