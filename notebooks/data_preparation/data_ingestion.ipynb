# %% [markdown]
# # Data Ingestion: Laptop Price Dataset

# %%
# Import libraries for system configuration
import os 
import sys 

sys.path.append(os.path.abspath(".."))

# Import libraries for data collection
import numpy as np 
import pandas as pd

# %% [markdown]
# ## Data Loading

# %%
# Import dataloader from script collector 
from scripts.collection.collector import DataLoader
from scripts.collection.ingestor import Ingestor

# %%
# Initialise variables 
data_folder = "data"
dataset_filename = "ebay_laptop_ds.csv"

# %%
# Create a data loader: load laptop dataset
data_loader = DataLoader(filename=dataset_filename, folder=data_folder)
laptop_ds = data_loader.load()
laptop_ds
# Out:
# File accepted
#        Brand   Price Currency  Color  \
# 0      other  303.80        $   gray
# 1       dell  400.00        $  black
# 2       dell  175.00        $  black
# 3         hp   85.00        $  black
# 4       dell  101.25        $  other
# ...      ...     ...      ...    ...
# 4178   other  162.20        $  other
# 4179    acer   93.25        $  other
# 4180    dell  424.80        $  black
# 4181      hp   90.94        $  other
# 4182  lenovo  567.50        $  black
#
#                                                Features  \
# 0     Backlit Keyboard,  Built-in Microphone,  Built...
# 1     Backlit Keyboard, Bluetooth, Built-in Micropho...
# 2     10/100 LAN Card, Backlit Keyboard, Bluetooth, ...
# 3     Bluetooth, Built-in Microphone, Built-in Webca...
# 4     10/100 LAN Card, Built-in Microphone, Built-in...
# ...                                                 ...
# 4178                                                NaN
# 4179                                                NaN
# 4180  Touchscreen,  10/100 LAN Card,  Bluetooth,  Ba...
# 4181                                                NaN
# 4182                                                NaN
#
#                     Condition  \
# 0                         New
# 1     Very Good - Refurbished
# 2                        Used
# 3          Good - Refurbished
# 4          Good - Refurbished
# ...                       ...
# 4178                      New
# 4179                      New
# 4180                     Used
# 4181                      New
# 4182                Undefined
#
#                                   Condition Description  \
# 0     A brand-new, unused, unopened, undamaged item ...
# 1     The item shows minimal wear and is backed by a...
# 2     An item that has been used previously. The ite...
# 3     The item shows moderate wear and is backed by ...
# 4     The item shows moderate wear and is backed by ...
# ...                                                 ...
# 4178  A brand-new, unused, unopened, undamaged item ...
# 4179  A brand-new, unused, unopened, undamaged item ...
# 4180  An item that has been used previously. The ite...
# 4181  A brand-new, unused, unopened, undamaged item ...
# 4182                                          Undefined
#
#                                             Seller Note    GPU  \
# 0                                             undefined  intel
# 1     aaa pcs is a microsoft authorized refurbisher ...  intel
# 2     well kept, fully functional, includes battery,...  intel
# 3     1-year allstate warranty. the original hp char...  intel
# 4     laptops is tested & fully working with some si...  other
# ...                                                 ...    ...
# 4178                                          undefined  other
# 4179                                          undefined  other
# 4180                                          undefined  intel
# 4181                                          undefined  other
# 4182                                          undefined  other
#
#                          Processor  ... Height of the Display       OS  \
# 0                        quad core  ...                1440.0  windows
# 1     intel core i7 8th generation  ...                1080.0  windows
# 2              intel core i5-6300u  ...                1080.0  windows
# 3                  intel celeron n  ...                 768.0   chrome
# 4     intel core i5 6th generation  ...                 768.0  windows
# ...                            ...  ...                   ...      ...
# 4178                     undefined  ...                   NaN  unknown
# 4179                not applicable  ...                   NaN  unknown
# 4180  intel core i5 6th generation  ...                1080.0  windows
# 4181                not applicable  ...                   NaN  unknown
# 4182                     undefined  ...                   NaN  unknown
#
#      Storage Type  Hard Drive Capacity  Hard Drive Capacity Unit SSD Capacity  \
# 0             ssd                512.0                        gb          1.0
# 1             ssd                  2.0                        tb          NaN
# 2             ssd                500.0                        gb        500.0
# 3            emmc                 16.0                        gb          NaN
# 4             ssd                  NaN                   unknown        256.0
# ...           ...                  ...                       ...          ...
# 4178      unknown                  NaN                   unknown          NaN
# 4179      unknown                  NaN                   unknown          NaN
# 4180      unknown                  NaN                   unknown        120.0
# 4181      unknown                  NaN                   unknown          NaN
# 4182      unknown                  NaN                   unknown          NaN
#
#      SSD Capacity Unit  Screen Size (inch) Ram Size  Ram Size Unit
# 0                   tb                  14      8.0             gb
# 1              unknown                  14      NaN        unknown
# 2                   gb                  14     16.0             gb
# 3              unknown                11.6      4.0             gb
# 4                   gb                12.5      8.0             gb
# ...                ...                 ...      ...            ...
# 4178           unknown                 NaN      NaN        unknown
# 4179           unknown                 NaN      NaN        unknown
# 4180                gb                12.5      NaN        unknown
# 4181           unknown                 NaN      NaN        unknown
# 4182           unknown                 NaN      NaN        unknown
#
# [4183 rows x 24 columns]

# %% [markdown]
# ## ETL-Process

# %% [markdown]
# + **Extraction**: extract features from dataset
# + **Transformation**: create new 4 dataset and apply transformation operations
# + **Loading**: load the dataset into mysql database

# %% [markdown]
# **Extraction**

# %% [markdown]
# Features can be split into 4 main groups:
# + **Numerical Data**
# + **Categorical Data**
# + **Complex Data**: Feature, Selle Note and Condition Description

# %%
# Check feature types
# laptop_ds.info()
desc_data = pd.DataFrame()

# Create features for descriptive dataset
desc_data["DataTypes"] = laptop_ds.dtypes
desc_data["Nullvalues"] = laptop_ds.isnull().sum()

# desc_data.transpose()
desc_data["Uniques"] = laptop_ds.nunique()
desc_data["Values"] = laptop_ds.values[:][0]
desc_data["FeatureType"] = desc_data["Values"].apply(lambda x: "Categorical" if type(x) == str else "Numerical")

# Reshape dataset
desc_data = desc_data.reset_index().rename(columns={"index": "Properties"})
desc_data["FeatureType"] = desc_data[["Properties", "FeatureType"]].apply(lambda property: "Complex" if property["Properties"] in ["Features", "Condition Description", "Seller Note"] else property["FeatureType"], axis=1)
# desc_data[["DataTypes", "FeatureType"]]
desc_data
# Out:
#                   Properties DataTypes  Nullvalues  Uniques  \
# 0                      Brand    object           0       10
# 1                      Price   float64           0     2014
# 2                   Currency    object           0        1
# 3                      Color    object           0       20
# 4                   Features    object        2190      709
# 5                  Condition    object           0       10
# 6      Condition Description    object           0       10
# 7                Seller Note    object           0      795
# 8                        GPU    object           0        5
# 9                  Processor    object           0      413
# 10           Processor Speed    object        2093       97
# 11      Processor Speed Unit    object           0        3
# 12                      Type    object           0        2
# 13      Width of the Display   float64        2268       27
# 14     Height of the Display   float64        2268       28
# 15                        OS    object           0        6
# 16              Storage Type    object           0        5
# 17       Hard Drive Capacity   float64        3079       34
# 18  Hard Drive Capacity Unit    object           0        3
# 19              SSD Capacity   float64        2056       23
# 20         SSD Capacity Unit    object           0        3
# 21        Screen Size (inch)    object        1638       66
# 22                  Ram Size   float64        2531       18
# 23             Ram Size Unit    object           0        3
#
#                                                Values  FeatureType
# 0                                               other  Categorical
# 1                                               303.8    Numerical
# 2                                                   $  Categorical
# 3                                                gray  Categorical
# 4   Backlit Keyboard,  Built-in Microphone,  Built...      Complex
# 5                                                 New  Categorical
# 6   A brand-new, unused, unopened, undamaged item ...      Complex
# 7                                           undefined      Complex
# 8                                               intel  Categorical
# 9                                           quad core  Categorical
# 10                                               3.80  Categorical
# 11                                                GHz  Categorical
# 12                                    notebook/laptop  Categorical
# 13                                             2160.0    Numerical
# 14                                             1440.0    Numerical
# 15                                            windows  Categorical
# 16                                                ssd  Categorical
# 17                                              512.0    Numerical
# 18                                                 gb  Categorical
# 19                                                1.0    Numerical
# 20                                                 tb  Categorical
# 21                                                 14  Categorical
# 22                                                8.0    Numerical
# 23                                                 gb  Categorical

# %% [markdown]
# ## Data Transformation: Numerical Data

# %%
# Extract numerical data
numerical_data = desc_data[desc_data["FeatureType"] == "Numerical"]
numerical_data

# Extract features 
numerical_vars = numerical_data["Properties"].values 
laptop_ds_num = laptop_ds[numerical_vars]
laptop_ds_num
# Out:
#        Price  Width of the Display  Height of the Display  \
# 0     303.80                2160.0                 1440.0
# 1     400.00                1920.0                 1080.0
# 2     175.00                1920.0                 1080.0
# 3      85.00                1366.0                  768.0
# 4     101.25                1366.0                  768.0
# ...      ...                   ...                    ...
# 4178  162.20                   NaN                    NaN
# 4179   93.25                   NaN                    NaN
# 4180  424.80                1920.0                 1080.0
# 4181   90.94                   NaN                    NaN
# 4182  567.50                   NaN                    NaN
#
#       Hard Drive Capacity  SSD Capacity  Ram Size
# 0                   512.0           1.0       8.0
# 1                     2.0           NaN       NaN
# 2                   500.0         500.0      16.0
# 3                    16.0           NaN       4.0
# 4                     NaN         256.0       8.0
# ...                   ...           ...       ...
# 4178                  NaN           NaN       NaN
# 4179                  NaN           NaN       NaN
# 4180                  NaN         120.0       NaN
# 4181                  NaN           NaN       NaN
# 4182                  NaN           NaN       NaN
#
# [4183 rows x 6 columns]

# %% [markdown]
# ## Data Transformation: Categorical Data

# %%
# Check categorical features
categorical_data = desc_data[desc_data["FeatureType"] == "Categorical"]

# Extract categorical features 
categorical_vars = categorical_data["Properties"].values
laptop_ds_cat = laptop_ds[categorical_vars]
laptop_ds_cat
# Out:
#        Brand Currency  Color                Condition    GPU  \
# 0      other        $   gray                      New  intel
# 1       dell        $  black  Very Good - Refurbished  intel
# 2       dell        $  black                     Used  intel
# 3         hp        $  black       Good - Refurbished  intel
# 4       dell        $  other       Good - Refurbished  other
# ...      ...      ...    ...                      ...    ...
# 4178   other        $  other                      New  other
# 4179    acer        $  other                      New  other
# 4180    dell        $  black                     Used  intel
# 4181      hp        $  other                      New  other
# 4182  lenovo        $  black                Undefined  other
#
#                          Processor Processor Speed Processor Speed Unit  \
# 0                        quad core            3.80                  GHz
# 1     intel core i7 8th generation            4.20                  GHz
# 2              intel core i5-6300u            2.40                  GHz
# 3                  intel celeron n            2.40                  GHz
# 4     intel core i5 6th generation            1.40                  GHz
# ...                            ...             ...                  ...
# 4178                     undefined             NaN              unknown
# 4179                not applicable             NaN              unknown
# 4180  intel core i5 6th generation            2.80                  GHz
# 4181                not applicable             NaN              unknown
# 4182                     undefined             NaN              unknown
#
#                  Type       OS Storage Type Hard Drive Capacity Unit  \
# 0     notebook/laptop  windows          ssd                       gb
# 1     notebook/laptop  windows          ssd                       tb
# 2     notebook/laptop  windows          ssd                       gb
# 3     notebook/laptop   chrome         emmc                       gb
# 4     notebook/laptop  windows          ssd                  unknown
# ...               ...      ...          ...                      ...
# 4178            other  unknown      unknown                  unknown
# 4179            other  unknown      unknown                  unknown
# 4180  notebook/laptop  windows      unknown                  unknown
# 4181            other  unknown      unknown                  unknown
# 4182  notebook/laptop  unknown      unknown                  unknown
#
#      SSD Capacity Unit Screen Size (inch) Ram Size Unit
# 0                   tb                 14            gb
# 1              unknown                 14       unknown
# 2                   gb                 14            gb
# 3              unknown               11.6            gb
# 4                   gb               12.5            gb
# ...                ...                ...           ...
# 4178           unknown                NaN       unknown
# 4179           unknown                NaN       unknown
# 4180                gb               12.5       unknown
# 4181           unknown                NaN       unknown
# 4182           unknown                NaN       unknown
#
# [4183 rows x 15 columns]

# %%
# Extract processor speed feature from categorical + combine with numerical feature 
processor_speed = laptop_ds_cat["Processor Speed"]
laptop_ds_num = pd.concat([laptop_ds_num, processor_speed], axis=1)
laptop_ds_num
# Out:
#        Price  Width of the Display  Height of the Display  \
# 0     303.80                2160.0                 1440.0
# 1     400.00                1920.0                 1080.0
# 2     175.00                1920.0                 1080.0
# 3      85.00                1366.0                  768.0
# 4     101.25                1366.0                  768.0
# ...      ...                   ...                    ...
# 4178  162.20                   NaN                    NaN
# 4179   93.25                   NaN                    NaN
# 4180  424.80                1920.0                 1080.0
# 4181   90.94                   NaN                    NaN
# 4182  567.50                   NaN                    NaN
#
#       Hard Drive Capacity  SSD Capacity  Ram Size Processor Speed
# 0                   512.0           1.0       8.0            3.80
# 1                     2.0           NaN       NaN            4.20
# 2                   500.0         500.0      16.0            2.40
# 3                    16.0           NaN       4.0            2.40
# 4                     NaN         256.0       8.0            1.40
# ...                   ...           ...       ...             ...
# 4178                  NaN           NaN       NaN             NaN
# 4179                  NaN           NaN       NaN             NaN
# 4180                  NaN         120.0       NaN            2.80
# 4181                  NaN           NaN       NaN             NaN
# 4182                  NaN           NaN       NaN             NaN
#
# [4183 rows x 7 columns]

# %% [markdown]
# ## Data Transformation: Complex Data

# %%
# Transform data into complex data 
complex_data = desc_data[desc_data["FeatureType"] == "Complex"]
complex_features = complex_data["Properties"].values
complex_features

# Create a new complex ddata
laptop_ds_complex = laptop_ds[complex_features]
laptop_ds_complex
# Out:
#                                                Features  \
# 0     Backlit Keyboard,  Built-in Microphone,  Built...
# 1     Backlit Keyboard, Bluetooth, Built-in Micropho...
# 2     10/100 LAN Card, Backlit Keyboard, Bluetooth, ...
# 3     Bluetooth, Built-in Microphone, Built-in Webca...
# 4     10/100 LAN Card, Built-in Microphone, Built-in...
# ...                                                 ...
# 4178                                                NaN
# 4179                                                NaN
# 4180  Touchscreen,  10/100 LAN Card,  Bluetooth,  Ba...
# 4181                                                NaN
# 4182                                                NaN
#
#                                   Condition Description  \
# 0     A brand-new, unused, unopened, undamaged item ...
# 1     The item shows minimal wear and is backed by a...
# 2     An item that has been used previously. The ite...
# 3     The item shows moderate wear and is backed by ...
# 4     The item shows moderate wear and is backed by ...
# ...                                                 ...
# 4178  A brand-new, unused, unopened, undamaged item ...
# 4179  A brand-new, unused, unopened, undamaged item ...
# 4180  An item that has been used previously. The ite...
# 4181  A brand-new, unused, unopened, undamaged item ...
# 4182                                          Undefined
#
#                                             Seller Note
# 0                                             undefined
# 1     aaa pcs is a microsoft authorized refurbisher ...
# 2     well kept, fully functional, includes battery,...
# 3     1-year allstate warranty. the original hp char...
# 4     laptops is tested & fully working with some si...
# ...                                                 ...
# 4178                                          undefined
# 4179                                          undefined
# 4180                                          undefined
# 4181                                          undefined
# 4182                                          undefined
#
# [4183 rows x 3 columns]

# %% [markdown]
# ## Data Storage

# %%
# Import dependencies for storing datasets
from scripts.collection.collector import DataSaver

# %% [markdown]
# After transformation is completed, the remaining datasets will be stored to processed folder. These datasets are names as:
#
# + **Laptop_numerical_data**: dataset contains only numerical features
# + **Laptop_categorical_data**: dataset contains only categorical features and some irrelevant data
# + **Laptop_complex_data**: dataset contains only complex textual data useful for feature engineering

# %%
# Initialise path variables
data_dict = {}
data_dict["Laptop_numerical_data"] = laptop_ds_num
data_dict["Laptop_categorical_data"] = laptop_ds_cat
data_dict["Laptop_complex_data"] = laptop_ds_complex

# %%
# Intialise path variables 
data_folder_path = "data\processed"

# Instantiate DataSaver-object
datasaver = DataSaver(folder=data_folder_path)
datasaver.save(data_dict=data_dict)
# Out:
# File 1: dataset as Laptop_numerical_data.csv --> C:\Development\Projects\MachineLearning\Laptop-Price-Predictor-System\data\processed (Saving is successful
# File 2: dataset as Laptop_categorical_data.csv --> C:\Development\Projects\MachineLearning\Laptop-Price-Predictor-System\data\processed (Saving is successful
# File 3: dataset as Laptop_complex_data.csv --> C:\Development\Projects\MachineLearning\Laptop-Price-Predictor-System\data\processed (Saving is successful

# %% [markdown]
# **Coperation 2025                                                                                                    Creator by ADOAN MIAN**
