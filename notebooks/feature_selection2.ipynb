# %% [markdown]
# # Feature Selection

# %%
# Import libraries 
import pandas as pd 
import numpy as np 
import os
import sys

sys.path.append(os.path.abspath(".."))

# %% [markdown]
# ## Approach
#
# - Data Loading
# - Data Transformation
# - Feature Selection
# - Data Storage

# %%
# Implement functionalities
from scripts.collection.ingestor import FileIngestor

# %%
# Load 4 datasets 
ingestor = FileIngestor(folder=r"processed\v1")
hardware_data = ingestor.ingest("hardware_table.csv")
visual_data = ingestor.ingest("visual_table.csv")
information_data = ingestor.ingest("memory_table.csv")
processor_data= ingestor.ingest("processor_table.csv")

# hardware_data
# information_data
# visual_data
processor_data
# Out:
#      PROCESSOR_ID                     PROCESSOR  PROCESSOR_SPEED  \
# 0              P0                     quad core              3.8
# 1              P1           intel core i5-6300u              2.4
# 2              P2               intel celeron n              2.4
# 3              P3  intel core i5 6th generation              1.4
# 4              P4                 intel celeron              1.6
# ...           ...                           ...              ...
# 4177        P4177                     undefined              0.0
# 4178        P4178                not applicable              0.0
# 4179        P4179  intel core i5 6th generation              2.8
# 4180        P4180                not applicable              0.0
# 4181        P4181                     undefined              0.0
#
#      PROCESSOR_SPEED_UNIT
# 0                     GHz
# 1                     GHz
# 2                     GHz
# 3                     GHz
# 4                     GHz
# ...

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# Datasets that need to be cleaned:
# - Information data
# - Visual data

# %% [markdown]
# ## Feature Selection

# %%
# Import functionalities 
from scripts.features.feature_selector import FeatureSelector
from scripts.processing.transformer import ColumnTransformer

# %% [markdown]
# For model development, these following features will be selected for processing and training:
# Hardware data:
# - GPU
# -

# %%
# Select features from 4 different datasets
selector1 = FeatureSelector(dataset=hardware_data)
selector2 = FeatureSelector(dataset=information_data)
selector3 =  FeatureSelector(dataset=processor_data)
selector4 = FeatureSelector(dataset=visual_data)

selector1.select()
