# %% [markdown]
# # Data Preparation P2

# %%
# Import libraries for system configuration
import os 
import sys 

sys.path.append(os.path.abspath(".."))

# Import libraries for data collection
import numpy as np 
import pandas as pd

# %% [markdown]
# ## Goal
#
# Consult datasets from mysql workbench for further use.
