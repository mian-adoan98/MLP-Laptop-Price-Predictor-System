# %% [markdown]
# # Data Ingestion: Test 1

# %%
import mysql.connector

# %% [markdown]
# Test goals:
#
# + Connect python with mysql workbench
# + Activate the database
# + Load the dataset from database
